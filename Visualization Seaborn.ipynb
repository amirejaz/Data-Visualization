# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)
# sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter') it is by default scatter

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', sizes=(15,200), data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', size='size', sizes=(15,200), data=tips)
plt.title('My seaborn visualization')
# Out:
# Text(0.5, 1.0, 'My seaborn visualization')

# %% [markdown]
# # Categorical plotting - catplot

# %% [markdown]
# # 1 Categorical scatter plotting

# %% [raw]
# # it contains two functions
# # 1 - Stripplot -- by default
# # 2 - Swarmplot
#
# x-axis = categorical data
# y-axis = numerical data

# %%
sns.catplot(x='day', y='tip', kind='strip', data=tips)

# %%
sns.catplot(x='day', y='tip', kind='strip', jitter=0, data=tips)

# %%
#for swarmplot
sns.catplot(x='day', y='tip', kind='swarm',data=tips)
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', kind='swarm', hue='sex', data=tips)
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # 2 Categorical Distribution Plot

# %% [raw]
# # it contains two functions
# # 1 - Boxplot -- by default
# # 2 - Violinplot

# %%
# boxplots are of two types :- univariate and multivariate

# %%
# univariate

sns.boxplot(tips['total_bill'])
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
#multivariate
sns.catplot(x='day', y='total_bill', kind='box', data=tips)

# %%
sns.catplot(x='day', y='total_bill', hue='sex', kind='box', data=tips)

# %%
#Violinplot

# %%
sns.violinplot(tips['total_bill'])
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', kind='violin', data=tips)

# %%
sns.catplot(x='day', y='total_bill', hue='sex', split=True, kind='violin', data=tips)

# %% [markdown]
# # 2 Categorical estimate plotting

# %% [raw]
# # it consists of three functions
# # 1 - pointplot not using
# # 2 - barplot
# # 3 - countplot

# %% [markdown]
# # Barplot and Countplot

# %%
# for barplot
sns.catplot(x='smoker', y='total_bill', kind='bar', data=tips)

# %%
sns.catplot(x='smoker', y='total_bill', hue='sex', kind='bar', estimator=np.mean, data=tips) 
# estimator is by default np.mean

# %%
sns.catplot(x='smoker', y='total_bill', kind='bar', hue='sex', estimator=np.median, data=tips)

# %%
#for countplot

# %%
# countplot only works for categorical data and similar to histogram

# %%
sns.catplot(x='sex', kind='count', data=tips)

# %%
sns.catplot(x='sex', hue='smoker', kind='count', data=tips)

# %% [markdown]
# # Categorical Categorical Plots

# %% [raw]
# it consits of two func
# 1 - heatmaps
# 2 - clustermaps

# %%
#for heatmaps 
# using different data set

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x = flights.pivot_table(index = 'year', columns='month', values='passengers', aggfunc='sum')

# %%
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x, cbar=False)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x, cbar=False, linewidths=0.5, annot=True, fmt='d')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x, cbar=False, linewidths=0.5, annot=True, fmt='d', cmap='summer')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# # Clustermap
# <!-- it recombine the similar rows and columns together -->

# %%
#it combines the similar rows and columns together

# %%
sns.clustermap(x)

# %%
sns.clustermap(x, z_score=0, metric='correlation')

# %%
sns.clustermap(x, z_score=0, annot=True, metric='correlation')

# %%
# if you don't want to cluster on the basis of rows then set (row_cluster = False)
sns.clustermap(x, z_score=0, annot=True, row_cluster=False, metric='correlation')

# %%
# if you don't want to cluster on the basis of columns then set (col_cluster = False)
sns.clustermap(x, z_score=0, annot=True, col_cluster=False, metric='correlation')

# %% [markdown]
# # side by side grapghs

# %% [raw]
# 1 - Jointplot
# we can use jointplot in following 4 manners:-
#     1 - scatterplot
#     2 - hexbin plot
#     3 - kdeplot
#     4 - Regplot

# %%
# for jointplot i am using tips dataset
sns.jointplot(x='total_bill', y='tip', kind='scatter', data=tips) #by default it is scatter
#histogram side by side

# %%
sns.jointplot(x='total_bill', y='tip', kind='hex', data=tips) 
#hex is basically a 2d histogram

# %%
sns.jointplot(x='total_bill', y='tip', kind='kde', data=tips)

#kde is basically a 2d PDF (probabilty density function)

# %%
sns.jointplot(x='total_bill', y='tip', kind='reg', data=tips)
#it is a regression plot and used for prediction

# %% [markdown]
# # Pair plot

# %%
# using iris dataset
# univariate distribution on diagonal

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# by default it will give a histogram diagonally
sns.pairplot(iris)

# %%
# by giving hue it will give pdf
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(flights)

# %% [markdown]
# # Distplot

# %% [raw]
# it combines 3 things:
#     1 - histogram
#     2 - kernal density estimation (kde) or pdf
#     3 - rugplot

# %%
# using titanic dataset
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic['age'])
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# only histogram
sns.distplot(titanic['age'], kde=False)
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>

# %%
#only kde
sns.distplot(titanic['age'], hist=False)
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic['age'], hist=False, kde=False, rug=True)
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>

# %%
#how to use distplot

# %%
sns.distplot(titanic[titanic['survived']==1]['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['survived']==1]['age'])
sns.distplot(titanic[titanic['survived']==0]['age'])
# Out:
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hunani Trading Co\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>
